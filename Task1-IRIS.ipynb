# %% [markdown]
# ## Name- Shraddha Gurav

# %% [markdown]
# # Task  1 - Iris DataSet

# %% [markdown]
# ##### Given the measurements of iris flowers according to their species... We have to train a machine learning model that can learn from the measurements of the iris species and classify them.

# %% [markdown]
# #### 1. Importing the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### 2. Loading the dataset into a dataframe

# %%
df = pd.read_csv("C:\\Users\\Shradha\\Downloads\\Iris.csv")

# %% [markdown]
# #### 3.1 Understanding the dataset

# %%
print('The top 5 rows of the dataset are')
print(df.head(5))
print()
print('The bottom 5 rows of the data set are')
print(df.tail(5))
# Out:
# The top 5 rows of the dataset are
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
# The bottom 5 rows of the data set are
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# ...

# %% [markdown]
# #### 3.2 Understanding the statistics of the dataset

# %%
print('The shape (rows, columns) of the dataset is as follows: ')
print(df.shape)
print()
print('The size if the dataset is:' ,df.size)
print()
print('The descriptive statistics of dataset is as follows')
print(df.describe())
# Out:
# The shape (rows, columns) of the dataset is as follows:
# (150, 6)
#
# The size if the dataset is: 900
#
# The descriptive statistics of dataset is as follows
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# #### 4.1 Comparitive visualization of Sepal Length vs Sepal Width for all species

# %%
plt.figure(figsize=(10,5))
plt.title('Comparison between various species based on sepal length and width')
plt.xlabel('Sepal Length')
plt.ylabel('Speal Width')
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue='Species', data=df, s=80 , marker = 'o')
# Out:
# <AxesSubplot:title={'center':'Comparison between various species based on sepal length and width'}, xlabel='Sepal Length', ylabel='Speal Width'>

# %% [markdown]
# ##### From the above graph we can conclude that from the three species, Iris - setosa has largest sepal width whereas Iris-sertosa has largest sepal length, meanwhile Iris - versicolor has moderate sepal length and sepal width lying evenlt between the sizes of Iris-setosa and Iris-virginica

# %% [markdown]
# #### 4.2 Comparitive visualization of Petal Length vs Petal Width for all species

# %%
plt.figure(figsize=(10,5))
plt.title('Comparison between various species based on sepal length and width')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm', hue='Species', data=df, s=80 , marker = 's')
# Out:
# <AxesSubplot:title={'center':'Comparison between various species based on sepal length and width'}, xlabel='Petal Length', ylabel='Petal Width'>

# %% [markdown]
# ##### From the above graph we conclude that from the three species, Iris - virginica has the largest petal length as well as petal width and Iris - setosa has the smallest petal length and petal width. Also, size of ppetal length and petal width of Iris - versicolor lies moderately between Iris - setosa and Iris - virginica

# %% [markdown]
# #### Data Modelling : Train-Test Split of data for evalutaing the performance of the machine learning algorithm.For splitting of dataset for training and testing we import train_test_split from sklearn.model_selection library.

# %%
from sklearn.model_selection import train_test_split
x = df.drop(columns = ['Species'])
y = df['Species']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.4)
y_test
# Out:
# 138     Iris-virginica
# 128     Iris-virginica
# 134     Iris-virginica
# 77     Iris-versicolor
# 109     Iris-virginica
# 78     Iris-versicolor
# 2          Iris-setosa
# 66     Iris-versicolor
# 26         Iris-setosa
# 90     Iris-versicolor
# 82     Iris-versicolor
# 124     Iris-virginica
# 86     Iris-versicolor
# 117     Iris-virginica
# 3          Iris-setosa
# 7          Iris-setosa
# 39         Iris-setosa
# 46         Iris-setosa
# 65     Iris-versicolor
# 148     Iris-virginica
# 16         Iris-setosa
# 72     Iris-versicolor
# 144     Iris-virginica
# 13         Iris-setosa
# 110     Iris-virginica
# 146     Iris-virginica
# 67     Iris-versicolor
# 127     Iris-virginica
# 123     Iris-virginica
# 6          Iris-setosa
# 131     Iris-virginica
# 108     Iris-virginica
# 62     Iris-versicolor
# 92     Iris-versicolor
# 19         Iris-setosa
# 80     Iris-versicolor
# 15         Iris-setosa
# 115     Iris-virginica
# 61     Iris-versicolor
# 18         Iris-setosa
# ...

# %% [markdown]
# #### Confusion Matrix : The confusion matrix is a matrix used to determine the performance of the classification models for a given set of test data. It can only be determined if the true values for test data are known. The matrix itself can be easily understood, but the related terminologies may be confusing. Since it shows the errors in the model performance in the form of a matrix, hence also known as an error matrix.

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
#Importing library foe decision classifier
from sklearn.tree import DecisionTreeClassifier
id3=DecisionTreeClassifier(criterion='entropy')
#Fit the data
k=id3.fit(x_train,y_train)
#predict the data
y_pred=id3.predict(x_test)
cm=confusion_matrix(y_pred,y_test)
plt.figure(figsize=(10,8))
sns.heatmap(cm,annot=True)
plt.xlabel('predicted-y')
plt.ylabel('actual-y')
plt.show()

# %% [markdown]
# ##### Model accuracy score represents the model’s ability to correctly predict both the positives and negatives out of all the predictions.
# ##### Accuracy Score = (TP + TN)/ (TP + FN + TN + FP)
# ##### Accuracy score is calculated between predicted output value and test value Model score is calculated between output and input values of testing.

# %%
print(classification_report(y_pred,y_test))
print('accuracy-score',accuracy_score(y_pred,y_test))
print('Model score',id3.score(x_test,y_test))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       1.00      1.00      1.00        19
#  Iris-virginica       1.00      1.00      1.00        23
#
#        accuracy                           1.00        60
#       macro avg       1.00      1.00      1.00        60
#    weighted avg       1.00      1.00      1.00        60
#
# accuracy-score 1.0
# Model score 1.0
